# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pathlib import Path as P
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# SOC: 土壤有机碳
# SIC: 土壤无机碳
# STC: 土壤全碳
# TN: 全N
# C/N: 土壤C/N比

# %%
excel=pd.ExcelFile('./数据集/监测点数据/附件14：内蒙古自治区锡林郭勒盟典型草原不同放牧强度土壤碳氮监测数据集（2012年8月15日-2020年8月15日）/内蒙古自治区锡林郭勒盟典型草原不同放牧强度土壤碳氮监测数据集（2012年8月15日-2020年8月15日）.xlsx')
df=excel.parse(sheet_name='data')
df
# Out:
#      year 放牧小区（plot） 放牧强度（intensity）   SOC土壤有机碳   SIC土壤无机碳    STC土壤全碳  \
# 0    2012        G17              NG  17.051564  11.300000  28.351564
# 1    2012        G19              NG  19.529439  11.333333  30.862772
# 2    2012        G21              NG  14.549908   9.600000  24.149908
# 3    2012         G6             LGI  18.672931  12.666667  31.339598
# 4    2012        G12             LGI  13.904905   8.133333  22.038239
# ..    ...        ...             ...        ...        ...        ...
# 127  2020        G11             MGI  14.744350   3.353600  18.097950
# 128  2020        G16             MGI  14.777000   9.819450  24.596450
# 129  2020         G9             HGI  17.200000   3.122150  20.322150
# 130  2020        G13             HGI  16.691900   3.564700  20.256600
# 131  2020        G20             HGI  15.969600   4.657050  20.626650
#
#           全氮N     土壤C/N比
# 0    2.192376  12.931887
# 1    1.883051  16.389768
# 2    1.871001  13.818022
# ...

# %%
df.columns
# Out:
# Index(['year', '放牧小区（plot）', '放牧强度（intensity）', 'SOC土壤有机碳', 'SIC土壤无机碳',
#        'STC土壤全碳', '全氮N', '土壤C/N比'],
#       dtype='object')

# %%
X_LIST=['year', '放牧小区（plot）', '放牧强度（intensity）']
Y_LIST=['SOC土壤有机碳', 'SIC土壤无机碳','STC土壤全碳', '全氮N', '土壤C/N比']
GROUP_LIST=['放牧小区（plot）', '放牧强度（intensity）']

# %%
df = df.groupby(X_LIST).mean().reset_index()

# %%
df.info() # 没有空值，所给的列都是需要的
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             60 non-null     int64
#  1   放牧小区（plot）       60 non-null     object
#  2   放牧强度（intensity）  60 non-null     object
#  3   SOC土壤有机碳         60 non-null     float64
#  4   SIC土壤无机碳         60 non-null     float64
#  5   STC土壤全碳          60 non-null     float64
#  6   全氮N              60 non-null     float64
#  7   土壤C/N比           60 non-null     float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 3.9+ KB

# %%
df.to_csv('问题3-附件14.csv', index=False)

# %%
df.groupby(GROUP_LIST)
