# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pathlib import Path as P
import matplotlib.pyplot as plt
import plotly.express as px

YEAR='年份'
BLOCK='放牧小区Block'
INTENSITY='放牧强度（intensity）'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_H=pd.read_csv('./附件3-湿度-预处理.csv', index_col='time')
df14=pd.read_csv('问题3-附件14.csv')
df15=pd.read_csv('问题1-附件15.csv', index_col='日期')
df15.index.name='time'

# %%
df_H.columns,df14.columns,df15.columns
# Out:
# (Index(['month', 'year', '10cm湿度(kg/m2)', '40cm湿度(kg/m2)', '100cm湿度(kg/m2)',
#         '200cm湿度(kg/m2)'],
#        dtype='object'),
#  Index(['year', '放牧小区（plot）', '放牧强度（intensity）', 'SOC土壤有机碳', 'SIC土壤无机碳',
#         'STC土壤全碳', '全氮N', '土壤C/N比'],
#        dtype='object'),
#  Index(['年份', '轮次', '处理', '放牧小区Block', '干重(g)'], dtype='object'))

# %%
df_H=df_H[['10cm湿度(kg/m2)', '40cm湿度(kg/m2)', '100cm湿度(kg/m2)',
        '200cm湿度(kg/m2)']]
df14=df14[['year', '放牧小区（plot）', '放牧强度（intensity）']]

# %%
df_H
# Out:
#             10cm湿度(kg/m2)  40cm湿度(kg/m2)  100cm湿度(kg/m2)  200cm湿度(kg/m2)
# time
# 2012-01-01          13.73          30.87           42.79          168.56
# 2012-02-01          13.00          30.87           42.79          168.56
# 2012-03-01          12.60          30.87           42.79          168.56
# 2012-04-01          11.97          30.73           42.76          168.56
# 2012-05-01          14.18          29.99           42.58          168.56
# ...                   ...            ...             ...             ...
# 2021-11-01          13.91          52.17           93.43          164.49
# 2021-12-01          13.14          52.14           93.45          164.48
# 2022-01-01          12.45          52.14           93.45          164.48
# 2022-02-01          12.10          52.14           93.45          164.48
# 2022-03-01          14.96          52.13           93.44          164.48
#
# [123 rows x 4 columns]

# %%
df15
# Out:
#               年份     轮次       处理 放牧小区Block    干重(g)
# time
# 2016-06-01  2016     牧前   中牧（6天）       G11   363.80
# 2016-06-01  2016     牧前   中牧（6天）       G16   320.09
# 2016-06-01  2016     牧前   中牧（6天）        G8   383.44
# 2016-06-01  2016     牧前   无牧（0天）       G17   297.32
# 2016-06-01  2016     牧前   无牧（0天）       G19   259.70
# ...          ...    ...      ...       ...      ...
# 2020-09-17  2020  第四轮牧后   轻牧（3天）       G18  1198.35
# 2020-09-17  2020  第四轮牧后   轻牧（3天）        G6  1597.61
# 2020-09-17  2020  第四轮牧后  重牧（12天）       G13  1062.98
# 2020-09-17  2020  第四轮牧后  重牧（12天）       G20   787.06
# 2020-09-17  2020  第四轮牧后  重牧（12天）        G9   740.23
#
# [298 rows x 5 columns]

# %%
sorted(df14['放牧小区（plot）'].unique())
# Out:
# ['G11',
#  'G12',
#  'G13',
#  'G16',
#  'G17',
#  'G18',
#  'G19',
#  'G20',
#  'G21',
#  'G6',
#  'G8',
#  'G9']

# %%
sorted(df15['放牧小区Block'].unique())
# Out:
# ['G11',
#  'G12',
#  'G13',
#  'G16',
#  'G17',
#  'G18',
#  'G19',
#  'G20',
#  'G21',
#  'G6',
#  'G8',
#  'G9']

# %%
df15['处理'].unique()
# Out:
# array(['中牧（6天）', '无牧（0天）', '轻牧（3天）', '重牧（12天）'], dtype=object)

# %%
df14['放牧强度（intensity）'].unique()
# Out:
# array(['MGI', 'LGI', 'HGI', 'NG'], dtype=object)

# %%
df14.rename(columns={
    'year': YEAR, '放牧小区（plot）': BLOCK,
})
